# %%
import pandas_datareader.data as pdr
import yfinance as yf
yf.pdr_override()
pdr.get_data_yahoo('AAPL')
# Out:
# yfinance: pandas_datareader support is deprecated & semi-broken so will be removed in a future verison. Just use yfinance.
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099192
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094017
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087116
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089273
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091861
# ...                ...         ...         ...         ...         ...
# 2024-06-14  213.850006  215.169998  211.300003  212.490005  212.490005
# 2024-06-17  213.369995  218.949997  212.720001  216.669998  216.669998
# 2024-06-18  217.589996  218.630005  213.000000  214.289993  214.289993
# ...

# %%
# list 快速建立
[i for i in range(5,10)]
# Out:
# [5, 6, 7, 8, 9]

# %%
{item:0 for item in['AAPL', 'MSFT', 'NVDA', 'PLTR']}
# Out:
# {'AAPL': 0, 'MSFT': 0, 'NVDA': 0, 'PLTR': 0}

# %%
# 快速建立 Dict
# key 裡面放入 DataFrame

all_data = {item:pdr.get_data_yahoo(item) for item in ['AAPL', 'MSFT', 'NVDA', 'PLTR']}
all_data
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# {'AAPL':                   Open        High         Low       Close   Adj Close  \
#  Date
#  1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099192
#  1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094017
#  1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087117
#  1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089273
#  1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091861
#  ...                ...         ...         ...         ...         ...
#  2024-06-14  213.850006  215.169998  211.300003  212.490005  212.490005
#  2024-06-17  213.369995  218.949997  212.720001  216.669998  216.669998
# ...

# %%
test = {item:0 for item in ['AAPL', 'MSFT', 'NVDA', 'PLTR']}  #製作 Dict
for key,value in test.items():     #tuple
    print(key)
    print(value)
# Out:
# AAPL
# 0
# MSFT
# 0
# NVDA
# 0
# PLTR
# 0

# %%
all_data = {item:pdr.get_data_yahoo(item) for item in ['AAPL', 'MSFT', 'NVDA', 'PLTR']}
{key:df['Adj Close'] for key,df in all_data.items()}    #key 裡面value放置 Series
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# {'AAPL': Date
#  1980-12-12      0.099192
#  1980-12-15      0.094017
#  1980-12-16      0.087116
#  1980-12-17      0.089273
#  1980-12-18      0.091861
#                   ...
#  2024-06-14    212.490005
#  2024-06-17    216.669998
#  2024-06-18    214.289993
#  2024-06-20    209.679993
#  2024-06-21    211.059998
#  Name: Adj Close, Length: 10972, dtype: float64,
#  'MSFT': Date
#  1986-03-13      0.060163
#  1986-03-14      0.062311
#  1986-03-17      0.063386
#  1986-03-18      0.061774
#  1986-03-19      0.060700
#                   ...
#  2024-06-14    442.570007
#  2024-06-17    448.369995
#  2024-06-18    446.339996
#  2024-06-20    445.700012
#  2024-06-21    449.369995
# ...

# %%
import pandas as pd
pd.DataFrame({key:df['Adj Close'] for key, df in all_data.items()})
# Out:
#                   AAPL        MSFT        NVDA       PLTR
# Date
# 1980-12-12    0.099192         NaN         NaN        NaN
# 1980-12-15    0.094017         NaN         NaN        NaN
# 1980-12-16    0.087117         NaN         NaN        NaN
# 1980-12-17    0.089273         NaN         NaN        NaN
# 1980-12-18    0.091861         NaN         NaN        NaN
# ...                ...         ...         ...        ...
# 2024-06-14  212.490005  442.570007  131.880005  23.570000
# 2024-06-17  216.669998  448.369995  130.979996  25.020000
# 2024-06-18  214.289993  446.339996  135.580002  25.820000
# 2024-06-20  209.679993  445.700012  130.779999  25.559999
# 2024-06-21  211.279999  449.304993  129.852600  24.355000
#
# [10972 rows x 4 columns]
