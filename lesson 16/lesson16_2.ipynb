# %%
import numpy as np
array_2d = np.random.randint(50,100,size=(50,5))
array_2d
# Out:
# array([[55, 90, 71, 85, 79],
#        [83, 57, 94, 94, 93],
#        [85, 93, 68, 58, 58],
#        [64, 80, 94, 66, 59],
#        [92, 59, 91, 76, 50],
#        [79, 81, 57, 85, 64],
#        [71, 92, 89, 96, 78],
#        [66, 87, 98, 67, 58],
#        [78, 97, 87, 68, 59],
#        [91, 95, 52, 53, 89],
#        [71, 98, 99, 69, 74],
#        [88, 95, 60, 70, 88],
#        [62, 58, 92, 74, 53],
#        [99, 54, 52, 89, 89],
#        [89, 65, 66, 72, 65],
#        [88, 89, 79, 58, 51],
#        [90, 56, 65, 65, 86],
#        [51, 81, 62, 84, 90],
#        [95, 78, 70, 71, 68],
#        [75, 59, 52, 84, 74],
#        [85, 89, 51, 65, 85],
#        [78, 69, 52, 75, 65],
#        [96, 75, 60, 87, 50],
#        [79, 54, 83, 52, 75],
#        [89, 73, 64, 74, 51],
#        [60, 81, 81, 65, 75],
#        [51, 99, 72, 54, 61],
#        [97, 83, 78, 98, 92],
#        [59, 76, 89, 57, 60],
#        [77, 71, 55, 54, 71],
#        [59, 80, 94, 86, 93],
#        [98, 84, 64, 53, 87],
# ...
