# %% [markdown]
# 繪製圖表                  資料
# 1. figure實體 -畫布       X軸要呈現的資料
# 2. Axes實體 -圖表         Y軸要呈現的資料
# 使用Axes實體修改細節

# %%
student1 = {'chinese':78, 'english':80, 'math':92, 'history':75, 'discover':85} #元素數量要記得
student2 = {'chinese':92, 'english':60, 'math':85, 'history':62, 'discover':73}
# dict的實體 ->一定有一個class

keys = student1.keys()
# keys()：返回由字典键组成的一个新视图。
print(type(keys))
print(keys)   #類似list
subject:list[str] = list(keys)
print(subject)
# Out:
# <class 'dict_keys'>
# dict_keys(['chinese', 'english', 'math', 'history', 'discover'])
# ['chinese', 'english', 'math', 'history', 'discover']

# %%
values = student1.values()
print(values)  #list，裡面是整數

values1 = list(values)
values2 = list(student2.values())  #實體方法

subject, values1, values2  #傳出tuple
# Out:
# dict_values([78, 80, 92, 75, 85])
# (['chinese', 'english', 'math', 'history', 'discover'],
#  [78, 80, 92, 75, 85],
#  [92, 60, 85, 62, 73])

# %% [markdown]
# matplotlib.pyplot.figure
# - (num=None, figsize=None (Width, height in inches.), dpi=None (The resolution of the figure in dots-per-inch.), *, facecolor=None, edgecolor=None, frameon=True, FigureClass=<class 'matplotlib.figure.Figure'>, clear=False, **kwargs)[source]

# %% [markdown]
# matplotlib.figure.Figure.add_subplot
# - Figure.add_subplot(*args, **kwargs)
# - Add an Axes to the figure as part of a subplot arrangement.

# %% [markdown]
# matplotlib.axes.Axes.plot
# - Axes.plot(*args, scalex=True, scaley=True, data=None, **kwargs)[source]
# - Plot y versus x as lines and/or markers.

# %%
# 繪圖  dpi(解析度) facecolor(參考日本色票)
import matplotlib.pyplot as plt
figure = plt.figure(figsize=[6,4], dpi=250, facecolor='#81C7D4')
axes = figure.add_subplot(1, 1, 1)   #一欄一列

axes.plot(subject,values1) # (X軸,y軸)
axes.plot(subject,values2)

plt.show()

# %% [markdown]
# plot(x, y, 'go--', linewidth=2, markersize=12)
# plot(x, y, color='green', marker='o', linestyle='dashed', linewidth=2, markersize=12)

# %%
student1 = {'chinese':78, 'english':80, 'math':92, 'history':75, 'discover':85} #元素數量要記得
student2 = {'chinese':92, 'english':60, 'math':85, 'history':62, 'discover':73}

keys = student1.keys()
subject:list[str] = list(keys)
values = student1.values()
values1 = list(values)
values2 = list(student2.values())  

# 繪圖  dpi(解析度) facecolor(參考日本色票)
import matplotlib.pyplot as plt
figure = plt.figure(figsize=[6,4], dpi=250, facecolor='#81C7D4')
axes = figure.add_subplot(1, 1, 1)   #一欄一列

axes.plot(subject,values1, 'bo--') # (X軸,y軸, '[顏色][marker][style]')  
axes.plot(subject,values2, 'r*-.')

plt.show()

# %% [markdown]
# ### matplotlib.axes.Axes.grid
# - Axes.grid(visible=None, which='major', axis='both', **kwargs)[source]
# Configure the grid lines.
#
# ### axis{'both', 'x', 'y'}, optional
# -The axis to apply the changes on.
#
# ### matplotlib.axes.Axes.set_title
# -Axes.set_title(label, fontdict=None, loc=None, pad=None, *, y=None, **kwargs)[source]
# Set a title for the Axes.
#
# ### matplotlib.axes.Axes.legend
# -Axes.legend(*args, **kwargs)[source]
# Place a legend on the Axes.

# %%
# 用 axes實體 修改細節
student1 = {'chinese':78, 'english':80, 'math':92, 'history':75, 'discover':85} #元素數量要記得
student2 = {'chinese':92, 'english':60, 'math':85, 'history':62, 'discover':73}

keys = student1.keys()
subject:list[str] = list(keys)
values = student1.values()
values1 = list(values)
values2 = list(student2.values())  

# 繪圖  dpi(解析度) facecolor(參考日本色票)
import matplotlib.pyplot as plt
figure = plt.figure(figsize=[6,4], dpi=250, facecolor='#81C7D4')
axes = figure.add_subplot(1, 1, 1)   #一欄一列
axes.plot(subject,values1, 'bo--', label="student1") # (X軸,y軸, '[顏色][marker][style]')  
axes.plot(subject,values2, 'r*-.', label="student2")
axes.grid(axis='y')  #畫線 (決定x軸y軸還是兩者)
axes.set_title("student1 vs student2")
axes.set_xlabel("subjects")
axes.set_ylabel("scores")
axes.legend()   #顯示標記

print(axes.get_xticks())     #每個科目為一個座標
print(axes.get_yticks())
print(axes.get_xticklabels())

plt.show()
# Out:
# [0, 1, 2, 3, 4]
# [55. 60. 65. 70. 75. 80. 85. 90. 95.]
# [Text(0, 0, 'chinese'), Text(1, 0, 'english'), Text(2, 0, 'math'), Text(3, 0, 'history'), Text(4, 0, 'discover')]

# %%
student1 = {'chinese':78, 'english':80, 'math':92, 'history':75, 'discover':85} #元素數量要記得
student2 = {'chinese':92, 'english':60, 'math':85, 'history':62, 'discover':73}

keys = student1.keys()
subject:list[str] = list(keys)
values = student1.values()
values1 = list(values)
values2 = list(student2.values())  

# 繪圖  dpi(解析度) facecolor(參考日本色票)
import matplotlib.pyplot as plt
figure = plt.figure(figsize=[6,4], dpi=250, facecolor='#81C7D4')
axes = figure.add_subplot(1, 1, 1)   #一欄一列
axes.plot(subject,values1, 'bo--', label="student1") # (X軸,y軸, '[顏色][marker][style]')  
axes.plot(subject,values2, 'r*-.', label="student2")
axes.grid(axis='y')  #畫線 (決定x軸y軸還是兩者)
axes.set_title("student1 vs student2")
axes.set_xlabel("subjects")
axes.set_ylabel("scores")
axes.legend()   #顯示標記

print(axes.get_xticks())     #每個科目為一個座標
print(axes.get_yticks())
labels = axes.get_xticklabels()
print(labels)
for label in labels:
    print(label.get_text())
    print(label.get_position()[0])

plt.show()
# Out:
# [0, 1, 2, 3, 4]
# [55. 60. 65. 70. 75. 80. 85. 90. 95.]
# [Text(0, 0, 'chinese'), Text(1, 0, 'english'), Text(2, 0, 'math'), Text(3, 0, 'history'), Text(4, 0, 'discover')]
# chinese
# 0
# english
# 1
# math
# 2
# history
# 3
# discover
# 4

# %% [markdown]
# ### matplotlib.axes.Axes.annotate
# - Axes.annotate(text, xy, xytext=None, xycoords='data', textcoords=None, arrowprops=None, annotation_clip=None, **kwargs)[source]
# Annotate the point xy with text text.

# %%
student1 = {'chinese':78, 'english':80, 'math':92, 'history':75, 'discover':85} #元素數量要記得
student2 = {'chinese':92, 'english':60, 'math':85, 'history':62, 'discover':73}

keys = student1.keys()
subject:list[str] = list(keys)
values = student1.values()
values1 = list(values)
values2 = list(student2.values())  

# 繪圖  dpi(解析度) facecolor(參考日本色票)
import matplotlib.pyplot as plt
figure = plt.figure(figsize=[6,4], dpi=250, facecolor='#81C7D4')
axes = figure.add_subplot(1, 1, 1)   #一欄一列
axes.plot(subject,values1, 'bo--', label="student1") # (X軸,y軸, '[顏色][marker][style]')  
axes.plot(subject,values2, 'r*-.', label="student2")
axes.grid(axis='y')  #畫線 (決定x軸y軸還是兩者)
axes.set_title("student1 vs student2")
axes.set_xlabel("subjects")
axes.set_ylabel("scores")
axes.legend()   #顯示標記

#print(axes.get_xticks())     #每個科目為一個座標
#print(axes.get_yticks())
labels = axes.get_xticklabels()
#print(labels)
for text in labels:
    subject_name = text.get_text()
    score1 = student1[subject_name]
    x_value = text.get_position()[0]
    axes.annotate(str(score1),(x_value, score1+0.5))                 #annotate：註解
    score2 = student2[subject_name]
    axes.annotate(str(score2),(x_value, score2+0.5))

plt.show()
